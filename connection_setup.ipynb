# %%
import pyodbc
import urllib
import sqlalchemy
from sqlalchemy.engine import URL
from sqlalchemy import create_engine
import pandas as pd
from src import helpers as hs
import importlib

# %%
importlib.reload(hs)
sql = f"""
        SELECT season, home_team, away_team, q1_temp_f, q1_wx_conditions
        FROM NFLW_Weather
        WHERE season = 2021
        """
hs.sql_query(sql)
# Out:
#      season             home_team            away_team  q1_temp_f  \
# 0      2021  Tampa Bay Buccaneers       Dallas Cowboys         80
# 1      2021       Atlanta Falcons  Philadelphia Eagles         80
# 2      2021         Buffalo Bills  Pittsburgh Steelers         72
# 3      2021    Cincinnati Bengals    Minnesota Vikings         82
# 4      2021         Detroit Lions  San Francisco 49ers         80
# ..      ...                   ...                  ...        ...
# 278    2021      Tennessee Titans   Cincinnati Bengals         34
# 279    2021     Green Bay Packers  San Francisco 49ers         13
# 280    2021  Tampa Bay Buccaneers     Los Angeles Rams         54
# 281    2021    Kansas City Chiefs        Buffalo Bills         35
# 282    2021    Cincinnati Bengals     Los Angeles Rams         82
#
#             q1_wx_conditions
# 0    Humid and Partly Cloudy
# 1                      Clear
# 2              Mostly Cloudy
# 3                      Clear
# ...
